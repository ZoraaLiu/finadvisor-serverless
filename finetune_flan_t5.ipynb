# %%
from google.colab import drive
drive.mount('/content/drive')

FOLDERNAME = 'Comp4651/Project/finadvisor-serverless'
PROJECT_PATH = f'/content/drive/MyDrive/{FOLDERNAME}'

import os, sys
os.chdir(PROJECT_PATH)

sys.path.append(PROJECT_PATH)
# Out:
# Mounted at /content/drive

# %%
# %run src/train.py
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# You are using the default legacy behaviour of the <class 'transformers.models.t5.tokenization_t5.T5Tokenizer'>. This is expected, and simply means that the `legacy` (previous) behavior will be used so nothing changes for you. If you want to use the new behaviour, set `legacy=False`. This should only be set if you understand what it means, and thoroughly read the reason why this was added as explained in https://github.com/huggingface/transformers/pull/24565
# Manual loss: 4.408249378204346
# trainable params: 344,064 || all params: 77,305,216 || trainable%: 0.4451
#     <div>
#
#       <progress value='2022' max='2022' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [2022/2022 06:28, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>4.392200</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>4.334600</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>4.126500</td>
#     </tr>
#     <tr>
#       <td>150</td>
#       <td>3.825300</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>3.482100</td>
#     </tr>
#     <tr>
#       <td>250</td>
#       <td>3.191700</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>2.933600</td>
#     </tr>
#     <tr>
#       <td>350</td>
#       <td>2.654600</td>
#     </tr>
#     <tr>
#       <td>400</td>
#       <td>2.341500</td>
#     </tr>
#     <tr>
#       <td>450</td>
#       <td>2.158600</td>
#     </tr>
#     <tr>
#       <td>500</td>
#       <td>1.919900</td>
#     </tr>
#     <tr>
#       <td>550</td>
#       <td>1.710500</td>
#     </tr>
#     <tr>
#       <td>600</td>
#       <td>1.618900</td>
#     </tr>
#     <tr>
#       <td>650</td>
#       <td>1.378400</td>
#     </tr>
#     <tr>
#       <td>700</td>
#       <td>1.274200</td>
#     </tr>
#     <tr>
#       <td>750</td>
#       <td>1.187900</td>
#     </tr>
#     <tr>
#       <td>800</td>
#       <td>1.102900</td>
#     </tr>
#     <tr>
#       <td>850</td>
#       <td>1.081700</td>
#     </tr>
#     <tr>
#       <td>900</td>
#       <td>1.031400</td>
#     </tr>
#     <tr>
#       <td>950</td>
#       <td>0.977600</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>0.907100</td>
#     </tr>
#     <tr>
#       <td>1050</td>
#       <td>0.895000</td>
#     </tr>
#     <tr>
#       <td>1100</td>
#       <td>0.872900</td>
#     </tr>
#     <tr>
#       <td>1150</td>
#       <td>0.898100</td>
#     </tr>
#     <tr>
#       <td>1200</td>
#       <td>0.842300</td>
#     </tr>
#     <tr>
#       <td>1250</td>
#       <td>0.811100</td>
#     </tr>
#     <tr>
#       <td>1300</td>
#       <td>0.777700</td>
#     </tr>
#     <tr>
#       <td>1350</td>
#       <td>0.784100</td>
#     </tr>
#     <tr>
#       <td>1400</td>
#       <td>0.777300</td>
#     </tr>
#     <tr>
#       <td>1450</td>
#       <td>0.739900</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>0.706900</td>
#     </tr>
#     <tr>
#       <td>1550</td>
#       <td>0.733600</td>
#     </tr>
#     <tr>
#       <td>1600</td>
#       <td>0.739400</td>
#     </tr>
#     <tr>
#       <td>1650</td>
#       <td>0.668900</td>
#     </tr>
#     <tr>
#       <td>1700</td>
#       <td>0.717200</td>
#     </tr>
#     <tr>
#       <td>1750</td>
#       <td>0.700200</td>
#     </tr>
#     <tr>
#       <td>1800</td>
#       <td>0.643500</td>
#     </tr>
#     <tr>
#       <td>1850</td>
#       <td>0.719400</td>
#     </tr>
#     <tr>
#       <td>1900</td>
#       <td>0.695500</td>
#     </tr>
#     <tr>
#       <td>1950</td>
#       <td>0.714700</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>0.695700</td>
#     </tr>
#   </tbody>
# </table><p>

# %%
# %run src/evaluate.py
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json: 0.00B [00:00, ?B/s]
# model.safetensors:   0%|          | 0.00/308M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/147 [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# spiece.model:   0%|          | 0.00/792k [00:00<?, ?B/s]
# special_tokens_map.json: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# You are using the default legacy behaviour of the <class 'transformers.models.t5.tokenization_t5.T5Tokenizer'>. This is expected, and simply means that the `legacy` (previous) behavior will be used so nothing changes for you. If you want to use the new behaviour, set `legacy=False`. This should only be set if you understand what it means, and thoroughly read the reason why this was added as explained in https://github.com/huggingface/transformers/pull/24565
# ### Prompt
# Profile: aggressive saver.
# Window: last 30 days.
# Totals: Income USD 27,009; Spend USD 14,517; Net USD 12,492.
# Top spend: Rent:5695, Shopping:2175, Utilities:2070.
# Recurring: USD 5,837 across 1 items.
# Delivery orders (approx): 3.
# Task: Suggest 2-3 actionable steps to reduce spend with ~USD monthly savings estimates.
#
# **Suggestion:**
# - Recurring charges look high; cancel one unused subscription to save USD 1,527/month. - Rent is taking a large share of your budget; consider options like a roommate, renegotiating your lease, or planning for a move when feasible.
#
# ---
#
# ### Prompt
# Profile: stretched renter.
# Window: last 45 days.
# Totals: Income SGD 6,163; Spend SGD 26,800; Net SGD -20,637.
# Top spend: Rent:14724, Shopping:4535, Utilities:2339.
# Recurring: SGD 15,013 across 2 items.
# Delivery orders (approx): 0.
# Task: Suggest 2-3 actionable steps to reduce spend with ~SGD monthly savings estimates.
#
# **Suggestion:**
# - Recurring charges look high; cancel one unused subscription to save SGD 1,399/month. - Rent is taking a large share of your budget; consider options like a roommate, renegotiating your lease, or planning for a move when feasible.
#
# ---
#
# ### Prompt
# Profile: stretched renter.
# Window: last 365 days.
# Totals: Income USD 242,520; Spend USD 271,155; Net USD -28,635.
# Top spend: Rent:171312, Shopping:20963, Utilities:17852.
# Recurring: USD 174,084 across 2 items.
# Delivery orders (approx): 16.
# Task: Suggest 2-3 actionable steps to reduce spend with ~USD monthly savings estimates.
#
# **Suggestion:**
# - Recurring charges look high; cancel one unused subscription to save USD 63/month. - Rent is taking a large share of your budget; consider options like a roommate, renegotiating your lease, or planning for a move when feasible.
#
# ---
#
# ### Prompt
# Profile: aggressive saver.
# Window: last 365 days.
# Totals: Income HKD 309,456; Spend HKD 139,756; Net HKD 169,700.
# Top spend: Rent:48984, Utilities:21804, Shopping:20273.
# Recurring: HKD 50,999 across 1 items.
# Delivery orders (approx): 21.
# Task: Provide 2-3 practical budgeting suggestions with estimated HKD monthly savings.
#
# **Suggestion:**
# - Recurring charges look high; cancel one unused subscription to save HKD 59/month. - Rent is taking a large share of your budget; consider options like a roommate, renegotiating your lease, or planning for a move when feasible.
#
# ---
#
# ### Prompt
# Profile: aggressive saver.
# Window: last 365 days.
# Totals: Income SGD 447,864; Spend SGD 251,869; Net SGD 195,995.
# Top spend: Rent:161244, Shopping:26452, Groceries:13404.
# Recurring: SGD 162,864 across 1 items.
# Delivery orders (approx): 21.
# Task: Suggest 2-3 actionable steps to reduce spend with ~SGD monthly savings estimates.
#
# **Suggestion:**
# - Recurring charges look high; cancel one unused subscription to save SGD 499/month. - Rent is taking a large share of your budget; consider options like a roommate, renegotiating your lease, or planning for a move when feasible.
#
# ---
#
# ### Prompt
# Profile: unsteady-income spender.
# Window: last 7 days.
# Totals: Income SGD 0; Spend SGD 1,607; Net SGD -1,607.
# Top spend: Shopping:644, Groceries:412, Utilities:208.
# Recurring: SGD 208 across 2 items.
# Delivery orders (approx): 0.
# Task: Suggest 2-3 actionable steps to reduce spend with ~SGD monthly savings estimates.
#
# **Suggestion:**
# - Recurring charges look high; cancel one unused subscription to save SGD 1,527/month. - Shopping is taking a large share of your budget; consider options like a roommate, renegotiating your lease, or planning for a move when feasible.
#
# ---
#
# ### Prompt
# Profile: stretched renter.
# Window: last 30 days.
# Totals: Income SGD 21,213; Spend SGD 22,700; Net SGD -1,487.
# Top spend: Rent:15489, Shopping:2551, Dining:1290.
# Recurring: SGD 15,692 across 2 items.
# Delivery orders (approx): 4.
# Task: Provide 2-3 practical budgeting suggestions with estimated SGD monthly savings.
#
# **Suggestion:**
# - Recurring charges look high; cancel one unused subscription to save SGD 1,499/month. - Rent is taking a large share of your budget; consider options like a roommate, renegotiating your lease, or planning for a move when feasible.
#
# ---
#
# ### Prompt
# Profile: delivery-focused foodie.
# Window: last 180 days.
# Totals: Income SGD 116,976; Spend SGD 90,278; Net SGD 26,698.
# Top spend: Rent:39018, Shopping:12274, Utilities:11929.
# Recurring: SGD 39,936 across 1 items.
# Delivery orders (approx): 7.
# Task: Provide 2-3 practical budgeting suggestions with estimated SGD monthly savings.
#
# **Suggestion:**
# - Recurring charges look high; cancel one unused subscription to save SGD 962/month. - Rent is taking a large share of your budget; consider options like a roommate, renegotiating your lease, or planning for a move when feasible.
#
# ---
#
# ### Prompt
# Profile: subscription-maximizer.
# Window: last 30 days.
# Totals: Income SGD 22,428; Spend SGD 21,150; Net SGD 1,278.
# Top spend: Rent:13466, Shopping:1800, Utilities:1563.
# Recurring: SGD 13,741 across 2 items.
# Delivery orders (approx): 1.
# Task: Provide 2-3 practical budgeting suggestions with estimated SGD monthly savings.
#
# **Suggestion:**
# - Recurring charges look high; cancel one unused subscription to save SGD 1,278/month. - Rent is taking a large share of your budget; consider options like a roommate, renegotiating your lease, or planning for a move when feasible.
#
# ---
#
# ### Prompt
# Profile: aggressive saver.
# Window: last 180 days.
# Totals: Income USD 215,514; Spend USD 97,937; Net USD 117,577.
# Top spend: Rent:52782, Shopping:16737, Utilities:6919.
# Recurring: USD 53,202 across 1 items.
# Delivery orders (approx): 12.
# Task: Give 2-3 concrete budgeting tips with rough USD savings per month.
#
# **Suggestion:**
# - Recurring charges look high; cancel one unused subscription to save USD 63/month. - Rent is taking a large share of your budget; consider options like a roommate, renegotiating your lease, or planning for a move when feasible.
#
# ---
#
# ### Prompt
# Profile: aggressive saver.
# Window: last 180 days.
# Totals: Income HKD 192,648; Spend HKD 85,257; Net HKD 107,391.
# Top spend: Rent:41142, Shopping:11812, Utilities:9084.
# Recurring: HKD 41,652 across 1 items.
# Delivery orders (approx): 11.
# Task: Provide 2-3 practical budgeting suggestions with estimated HKD monthly savings.
#
# **Suggestion:**
# - Recurring charges look high; cancel one unused subscription to save HKD 962/month. - Rent is taking a large share of your budget; consider options like a roommate, renegotiating your lease, or planning for a move when feasible.
#
# ---
#
# ### Prompt
# Profile: aggressive saver.
# Window: last 365 days.
# Totals: Income HKD 385,296; Spend HKD 173,390; Net HKD 211,906.
# Top spend: Rent:82284, Shopping:22940, Utilities:14991.
# Recurring: HKD 83,304 across 1 items.
# Delivery orders (approx): 31.
# Task: Provide 2-3 practical budgeting suggestions with estimated HKD monthly savings.
#
# **Suggestion:**
# - Recurring charges look high; cancel one unused subscription to save HKD 632/month. - Rent is taking a large share of your budget; consider options like a roommate, renegotiating your lease, or planning for a move when feasible.
#
# ---
#
# ### Prompt
# Profile: subscription-maximizer.
# Window: last 30 days.
# Totals: Income SGD 18,043; Spend SGD 12,293; Net SGD 5,750.
# Top spend: Rent:6950, Groceries:1307, Entertainment:1180.
# Recurring: SGD 7,173 across 2 items.
# Delivery orders (approx): 2.
# Task: Suggest 2-3 actionable steps to reduce spend with ~SGD monthly savings estimates.
#
# **Suggestion:**
# - Recurring charges look high; cancel one unused subscription to save SGD 1,399/month. - Rent is taking a large share of your budget; consider options like a roommate, renegotiating your lease, or planning for a move when feasible.
#
# ---
#
# ### Prompt
# Profile: unsteady-income spender.
# Window: last 7 days.
# Totals: Income SGD 0; Spend SGD 1,928; Net SGD -1,928.
# Top spend: Shopping:696, Dining:317, Entertainment:286.
# Recurring: SGD 156 across 1 items.
# Delivery orders (approx): 1.
# Task: Suggest 2-3 actionable steps to reduce spend with ~SGD monthly savings estimates.
#
# **Suggestion:**
# - Recurring charges look high; cancel one unused subscription to save SGD 63/month. - Shopping is 27% of spend; 21% of spend is resable.
#
# ---
#
# ### Prompt
# Profile: delivery-focused foodie.
# Window: last 30 days.
# Totals: Income USD 30,077; Spend USD 21,365; Net USD 8,712.
# Top spend: Rent:11027, Shopping:2042, Groceries:1631.
# Recurring: USD 11,208 across 2 items.
# Delivery orders (approx): 6.
# Task: Provide 2-3 practical budgeting suggestions with estimated USD monthly savings.
#
# **Suggestion:**
# - Recurring charges look high; cancel one unused subscription to save USD 1,327/month. - Rent is taking a large share of your budget; consider options like a roommate, renegotiating your lease, or planning for a move when feasible.
#
# ---
#
# ### Prompt
# Profile: stretched renter.
# Window: last 365 days.
# Totals: Income HKD 213,420; Spend HKD 203,821; Net HKD 9,599.
# Top spend: Rent:117984, Shopping:24564, Utilities:12736.
# Recurring: HKD 118,992 across 1 items.
# Delivery orders (approx): 12.
# Task: Give 2-3 concrete budgeting tips with rough HKD savings per month.
#
# **Suggestion:**
# - Recurring charges look high; cancel one unused subscription to save HKD 63/month. - Rent is taking a large share of your budget; consider options like a roommate, renegotiating your lease, or planning for a move when feasible.
#
# ---
#
# ### Prompt
# Profile: stretched renter.
# Window: last 365 days.
# Totals: Income SGD 122,160; Spend SGD 171,286; Net SGD -49,126.
# Top spend: Rent:80316, Shopping:26803, Utilities:16953.
# Recurring: SGD 82,092 across 1 items.
# Delivery orders (approx): 13.
# Task: Give 2-3 concrete budgeting tips with rough SGD savings per month.
#
# **Suggestion:**
# - Recurring charges look high; cancel one unused subscription to save SGD 63/month. - Rent is taking a large share of your budget; consider options like a roommate, renegotiating your lease, or planning for a move when feasible.
#
# ---
#
# ### Prompt
# Profile: aggressive saver.
# Window: last 30 days.
# Totals: Income SGD 37,190; Spend SGD 14,543; Net SGD 22,647.
# Top spend: Rent:10330, Groceries:1101, Entertainment:1006.
# Recurring: SGD 10,402 across 1 items.
# Delivery orders (approx): 0.
# Task: Provide 2-3 practical budgeting suggestions with estimated SGD monthly savings.
#
# **Suggestion:**
# - Recurring charges look high; cancel one unused subscription to save SGD 1,528/month. - Rent is taking a large share of your budget; consider options like a roommate, renegotiating your lease, or planning for a move when feasible.
#
# ---
#
# ### Prompt
# Profile: subscription-maximizer.
# Window: last 30 days.
# Totals: Income SGD 15,031; Spend SGD 16,706; Net SGD -1,675.
# Top spend: Rent:8488, Utilities:2713, Groceries:2234.
# Recurring: SGD 8,626 across 1 items.
# Delivery orders (approx): 1.
# Task: Give 2-3 concrete budgeting tips with rough SGD savings per month.
#
# **Suggestion:**
# - Recurring charges look high; cancel one unused subscription to save SGD 1,567/month. - Rent is taking a large share of your budget; consider options like a roommate, renegotiating your lease, or planning for a move when feasible.
#
# ---
#
# ### Prompt
# Profile: aggressive saver.
# Window: last 180 days.
# Totals: Income SGD 169,050; Spend SGD 100,999; Net SGD 68,051.
# Top spend: Rent:58554, Utilities:9623, Shopping:8418.
# Recurring: SGD 58,992 across 1 items.
# Delivery orders (approx): 7.
# Task: Suggest 2-3 actionable steps to reduce spend with ~SGD monthly savings estimates.
#
# **Suggestion:**
# - Recurring charges look high; cancel one unused subscription to save SGD 962/month. - Rent is taking a large share of your budget; consider options like a roommate, renegotiating your lease, or planning for a move when feasible.
#
# ---
#
# ### Prompt
# Profile: unsteady-income spender.
# Window: last 7 days.
# Totals: Income SGD 0; Spend SGD 923; Net SGD -923.
# Top spend: Dining:462, Health:301, Other:160.
# Recurring: SGD 0 across 0 items.
# Delivery orders (approx): 2.
# Task: Suggest 2-3 actionable steps to reduce spend with ~SGD monthly savings estimates.
#
# **Suggestion:**
# - Recurring charges look high; cancel one unused subscription to save SGD 63/month. - Dining is taking a large share of your budget; consider options like a roommate, renegotiating your lease, or planning for a move when feasible.
#
# ---
#
# ### Prompt
# Profile: aggressive saver.
# Window: last 365 days.
# Totals: Income HKD 448,176; Spend HKD 168,472; Net HKD 279,704.
# Top spend: Rent:83424, Shopping:22569, Utilities:13931.
# Recurring: HKD 85,128 across 2 items.
# Delivery orders (approx): 17.
# Task: Provide 2-3 practical budgeting suggestions with estimated HKD monthly savings.
#
# **Suggestion:**
# - Recurring charges look high; cancel one unused subscription to save HKD 63/month. - Rent is taking a large share of your budget; consider options like a roommate, renegotiating your lease, or planning for a move when feasible.
#
# ---
#
# ### Prompt
# Profile: delivery-focused foodie.
# Window: last 365 days.
# Totals: Income HKD 149,808; Spend HKD 149,767; Net HKD 41.
# Top spend: Rent:65916, Shopping:23934, Utilities:11277.
# Recurring: HKD 67,080 across 1 items.
# Delivery orders (approx): 22.
# Task: Suggest 2-3 actionable steps to reduce spend with ~HKD monthly savings estimates.
#
# **Suggestion:**
# - Recurring charges look high; cancel one unused subscription to save HKD 67,080/month. - Rent is taking a large share of your budget; consider options like a roommate, renegotiating your lease, or planning for a move when feasible.
#
# ---
#
# ### Prompt
# Profile: delivery-focused foodie.
# Window: last 180 days.
# Totals: Income SGD 53,838; Spend SGD 79,739; Net SGD -25,901.
# Top spend: Rent:33846, Shopping:12707, Utilities:6951.
# Recurring: SGD 34,686 across 1 items.
# Delivery orders (approx): 6.
# Task: Give 2-3 concrete budgeting tips with rough SGD savings per month.
#
# **Suggestion:**
# - Recurring charges look high; cancel one unused subscription to save SGD 63/month. - Rent is taking a large share of your budget; consider options like a roommate, renegotiating your lease, or planning for a move when feasible.
#
# ---
#
# ### Prompt
# Profile: delivery-focused foodie.
# Window: last 365 days.
# Totals: Income SGD 196,704; Spend SGD 145,553; Net SGD 51,151.
# Top spend: Rent:59004, Shopping:21706, Utilities:13662.
# Recurring: SGD 60,432 across 1 items.
# Delivery orders (approx): 19.
# Task: Suggest 2-3 actionable steps to reduce spend with ~SGD monthly savings estimates.
#
# **Suggestion:**
# - Recurring charges look high; cancel one unused subscription to save SGD 63/month. - Rent is taking a large share of your budget; consider options like a roommate, renegotiating your lease, or planning for a move when feasible.
#
# ---
#
# ### Prompt
# Profile: comfortable renter.
# Window: last 180 days.
# Totals: Income SGD 198,888; Spend SGD 125,569; Net SGD 73,319.
# Top spend: Rent:79794, Groceries:9201, Shopping:8745.
# Recurring: SGD 80,334 across 1 items.
# Delivery orders (approx): 9.
# Task: Suggest 2-3 actionable steps to reduce spend with ~SGD monthly savings estimates.
#
# **Suggestion:**
# - Recurring charges look high; cancel one unused subscription to save SGD 632/month. - Rent is taking a large share of your budget; consider options like a roommate, renegotiating your lease, or planning for a move when feasible.
#
# ---
#
# ### Prompt
# Profile: aggressive saver.
# Window: last 45 days.
# Totals: Income SGD 29,696; Spend SGD 16,532; Net SGD 13,164.
# Top spend: Rent:5540, Utilities:3301, Shopping:3186.
# Recurring: SGD 5,832 across 1 items.
# Delivery orders (approx): 2.
# Task: Provide 2-3 practical budgeting suggestions with estimated SGD monthly savings.
#
# **Suggestion:**
# - Recurring charges look high; cancel one unused subscription to save SGD 1,399/month. - Rent is taking a large share of your budget; consider options like a roommate, renegotiating your lease, or planning for a move when feasible.
#
# ---
#
# ### Prompt
# Profile: aggressive saver.
# Window: last 365 days.
# Totals: Income SGD 423,240; Spend SGD 213,043; Net SGD 210,197.
# Top spend: Rent:124620, Shopping:31990, Utilities:12887.
# Recurring: SGD 125,880 across 1 items.
# Delivery orders (approx): 17.
# Task: Suggest 2-3 actionable steps to reduce spend with ~SGD monthly savings estimates.
#
# **Suggestion:**
# - Recurring charges look high; cancel one unused subscription to save SGD 632/month. - Rent is taking a large share of your budget; consider options like a roommate, renegotiating your lease, or planning for a move when feasible.
#
# ---
#
# ### Prompt
# Profile: unsteady-income spender.
# Window: last 7 days.
# Totals: Income USD 0; Spend USD 864; Net USD -864.
# Top spend: Other:423, Utilities:324, Transport:117.
# Recurring: USD 0 across 0 items.
# Delivery orders (approx): 0.
# Task: Provide 2-3 practical budgeting suggestions with estimated USD monthly savings.
#
# **Suggestion:**
# - Recurring charges look high; cancel one unused subscription to save USD 63/month. - Recurring charges look high; cancel one unused subscription to save USD 63/month. - Budget is a large share of your budget; consider options like a roommate, renegotiating your lease, or planning for a move when feasible.
#
# ---
#
# ### Prompt
# Profile: unsteady-income spender.
# Window: last 7 days.
# Totals: Income HKD 0; Spend HKD 2,267; Net HKD -2,267.
# Top spend: Shopping:1890, Entertainment:377.
# Recurring: HKD 0 across 0 items.
# Delivery orders (approx): 0.
# Task: Provide 2-3 practical budgeting suggestions with estimated HKD monthly savings.
#
# **Suggestion:**
# - Recurring charges look high; cancel one unused subscription to save HKD 1,267/month. - Shopping is 27% of spend; 9% of spend is taking a large share of your budget; consider options like a roommate, renegotiating your lease, or planning for a move when feasible.
#
# ---
#
# ### Prompt
# Profile: stretched renter.
# Window: last 180 days.
# Totals: Income HKD 99,768; Spend HKD 111,751; Net HKD -11,983.
# Top spend: Rent:57294, Shopping:16896, Utilities:8449.
# Recurring: HKD 58,068 across 2 items.
# Delivery orders (approx): 11.
# Task: Suggest 2-3 actionable steps to reduce spend with ~HKD monthly savings estimates.
#
# **Suggestion:**
# - Recurring charges look high; cancel one unused subscription to save HKD 59/month. - Rent is taking a large share of your budget; consider options like a roommate, renegotiating your lease, or planning for a move when feasible.
#
# ---
#
# ### Prompt
# Profile: stretched renter.
# Window: last 45 days.
# Totals: Income SGD 22,622; Spend SGD 25,852; Net SGD -3,230.
# Top spend: Rent:15848, Shopping:4267, Entertainment:2010.
# Recurring: SGD 15,927 across 1 items.
# Delivery orders (approx): 2.
# Task: Suggest 2-3 actionable steps to reduce spend with ~SGD monthly savings estimates.
#
# **Suggestion:**
# - Recurring charges look high; cancel one unused subscription to save SGD 1,227/month. - Rent is taking a large share of your budget; consider options like a roommate, renegotiating your lease, or planning for a move when feasible.
#
# ---
#
# ### Prompt
# Profile: unsteady-income spender.
# Window: last 7 days.
# Totals: Income USD 0; Spend USD 502; Net USD -502.
# Top spend: Other:299, Health:115, Groceries:88.
# Recurring: USD 0 across 0 items.
# Delivery orders (approx): 0.
# Task: Give 2-3 concrete budgeting tips with rough USD savings per month.
#
# **Suggestion:**
# - Recurring charges look high; cancel one unused subscription to save USD 63/month. - Recurring charges look high; cancel one unused subscription to save USD 63/month. - Budget is a big burden; consider options like a roommate, renegotiating your lease, or planning for a move when feasible.
#
# ---
#
# ### Prompt
# Profile: aggressive saver.
# Window: last 45 days.
# Totals: Income SGD 46,504; Spend SGD 27,698; Net SGD 18,806.
# Top spend: Rent:15088, Utilities:2899, Groceries:2264.
# Recurring: SGD 15,556 across 1 items.
# Delivery orders (approx): 5.
# Task: Give 2-3 concrete budgeting tips with rough SGD savings per month.
#
# **Suggestion:**
# - Recurring charges look high; cancel one unused subscription to save SGD 1,528/month. - Rent is taking a large share of your budget; consider options like a roommate, renegotiating your lease, or planning for a move when feasible.
#
# ---
#
# ### Prompt
# Profile: comfortable renter.
# Window: last 365 days.
# Totals: Income HKD 355,812; Spend HKD 243,840; Net HKD 111,972.
# Top spend: Rent:159744, Shopping:21699, Utilities:16402.
# Recurring: HKD 161,580 across 1 items.
# Delivery orders (approx): 19.
# Task: Give 2-3 concrete budgeting tips with rough HKD savings per month.
#
# **Suggestion:**
# - Recurring charges look high; cancel one unused subscription to save HKD 962/month. - Rent is taking a large share of your budget; consider options like a roommate, renegotiating your lease, or planning for a move when feasible.
#
# ---
#
# ### Prompt
# Profile: subscription-maximizer.
# Window: last 30 days.
# Totals: Income HKD 26,260; Spend HKD 21,501; Net HKD 4,759.
# Top spend: Rent:13365, Shopping:2404, Health:2174.
# Recurring: HKD 13,585 across 2 items.
# Delivery orders (approx): 2.
# Task: Suggest 2-3 actionable steps to reduce spend with ~HKD monthly savings estimates.
#
# **Suggestion:**
# - Recurring charges look high; cancel one unused subscription to save HKD 1,599/month. - Rent is taking a large share of your budget; consider options like a roommate, renegotiating your lease, or planning for a move when feasible.
#
# ---
#
# ### Prompt
# Profile: stretched renter.
# Window: last 45 days.
# Totals: Income USD 40,420; Spend USD 40,526; Net USD -106.
# Top spend: Rent:28552, Utilities:3179, Entertainment:2178.
# Recurring: USD 29,014 across 2 items.
# Delivery orders (approx): 2.
# Task: Suggest 2-3 actionable steps to reduce spend with ~USD monthly savings estimates.
#
# **Suggestion:**
# - Recurring charges look high; cancel one unused subscription to save USD 1,378/month. - Rent is taking a large share of your budget; consider options like a roommate, renegotiating your lease, or planning for a move when feasible.
#
# ---
#
# ### Prompt
# Profile: unsteady-income spender.
# Window: last 7 days.
# Totals: Income HKD 0; Spend HKD 2,076; Net HKD -2,076.
# Top spend: Groceries:564, Entertainment:528, Utilities:477.
# Recurring: HKD 250 across 2 items.
# Delivery orders (approx): 0.
# Task: Provide 2-3 practical budgeting suggestions with estimated HKD monthly savings.
#
# **Suggestion:**
# - Recurring charges look high; cancel one unused subscription to save HKD 1,076/month. - Budget is a big part of your budget; consider options like a roommate, renegotiating your lease, or planning for a move when feasible.
#
# ---
#
# ### Prompt
# Profile: subscription-maximizer.
# Window: last 30 days.
# Totals: Income SGD 33,148; Spend SGD 20,893; Net SGD 12,255.
# Top spend: Rent:13299, Groceries:1991, Shopping:1698.
# Recurring: SGD 13,389 across 1 items.
# Delivery orders (approx): 1.
# Task: Provide 2-3 practical budgeting suggestions with estimated SGD monthly savings.
#
# **Suggestion:**
# - Recurring charges look high; cancel one unused subscription to save SGD 1,399/month. - Rent is taking a large share of your budget; consider options like a roommate, renegotiating your lease, or planning for a move when feasible.
#
# ---
#
# ### Prompt
# Profile: aggressive saver.
# Window: last 30 days.
# Totals: Income SGD 32,674; Spend SGD 17,823; Net SGD 14,851.
# Top spend: Rent:8382, Shopping:2725, Groceries:1855.
# Recurring: SGD 8,534 across 1 items.
# Delivery orders (approx): 1.
# Task: Provide 2-3 practical budgeting suggestions with estimated SGD monthly savings.
#
# **Suggestion:**
# - Recurring charges look high; cancel one unused subscription to save SGD 1,528/month. - Rent is taking a large share of your budget; consider options like a roommate, renegotiating your lease, or planning for a move when feasible.
#
# ---
#
# ### Prompt
# Profile: comfortable renter.
# Window: last 180 days.
# Totals: Income USD 155,454; Spend USD 124,220; Net USD 31,234.
# Top spend: Rent:72960, Shopping:14113, Dining:6724.
# Recurring: USD 74,262 across 2 items.
# Delivery orders (approx): 15.
# Task: Provide 2-3 practical budgeting suggestions with estimated USD monthly savings.
#
# **Suggestion:**
# - Recurring charges look high; cancel one unused subscription to save USD 63/month. - Rent is taking a large share of your budget; consider options like a roommate, renegotiating your lease, or planning for a move when feasible.
#
# ---
#
# ### Prompt
# Profile: unsteady-income spender.
# Window: last 7 days.
# Totals: Income SGD 0; Spend SGD 847; Net SGD -847.
# Top spend: Dining:620, Transport:127, Health:100.
# Recurring: SGD 0 across 0 items.
# Delivery orders (approx): 2.
# Task: Give 2-3 concrete budgeting tips with rough SGD savings per month.
#
# **Suggestion:**
# - Recurring charges look high; cancel one unused subscription to save SGD 0/month. - Budget is a big part of your budget; consider options like a roommate, renegotiating your lease, or planning for a move when feasible.
#
# ---
#
# ### Prompt
# Profile: unsteady-income spender.
# Window: last 7 days.
# Totals: Income SGD 0; Spend SGD 2,385; Net SGD -2,385.
# Top spend: Utilities:995, Shopping:802, Other:386.
# Recurring: SGD 105 across 1 items.
# Delivery orders (approx): 0.
# Task: Give 2-3 concrete budgeting tips with rough SGD savings per month.
#
# **Suggestion:**
# - Recurring charges look high; cancel one unused subscription to save SGD 63/month. - Shopping is 27% of spend; 39-month rule is a minimum for a month.
#
# ---
#
# ### Prompt
# Profile: stretched renter.
# Window: last 45 days.
# Totals: Income SGD 2,037; Spend SGD 22,628; Net SGD -20,591.
# Top spend: Rent:14829, Shopping:3152, Groceries:1420.
# Recurring: SGD 15,044 across 2 items.
# Delivery orders (approx): 3.
# Task: Give 2-3 concrete budgeting tips with rough SGD savings per month.
#
# **Suggestion:**
# - Recurring charges look high; cancel one unused subscription to save SGD 1,037/month. - Rent is taking a large share of your budget; consider options like a roommate, renegotiating your lease, or planning for a move when feasible.
#
# ---
#
# ### Prompt
# Profile: subscription-maximizer.
# Window: last 30 days.
# Totals: Income SGD 19,261; Spend SGD 18,281; Net SGD 980.
# Top spend: Rent:10931, Shopping:1516, Dining:1272.
# Recurring: SGD 11,139 across 2 items.
# Delivery orders (approx): 0.
# Task: Provide 2-3 practical budgeting suggestions with estimated SGD monthly savings.
#
# **Suggestion:**
# - Recurring charges look high; cancel one unused subscription to save SGD 1,299/month. - Rent is taking a large share of your budget; consider options like a roommate, renegotiating your lease, or planning for a move when feasible.
#
# ---
#
# ### Prompt
# Profile: shopper with flexible spend.
# Window: last 45 days.
# Totals: Income USD 19,691; Spend USD 21,366; Net USD -1,675.
# Top spend: Rent:9539, Shopping:4391, Groceries:2152.
# Recurring: USD 9,654 across 1 items.
# Delivery orders (approx): 1.
# Task: Suggest 2-3 actionable steps to reduce spend with ~USD monthly savings estimates.
#
# **Suggestion:**
# - Recurring charges look high; cancel one unused subscription to save USD 1,399/month. - Rent is taking a large share of your budget; consider options like a roommate, renegotiating your lease, or planning for a move when feasible.
#
# ---
#
# ### Prompt
# Profile: subscription-maximizer.
# Window: last 30 days.
# Totals: Income HKD 8,619; Spend HKD 16,461; Net HKD -7,842.
# Top spend: Rent:8441, Shopping:2132, Dining:1586.
# Recurring: HKD 8,706 across 2 items.
# Delivery orders (approx): 2.
# Task: Give 2-3 concrete budgeting tips with rough HKD savings per month.
#
# **Suggestion:**
# - Recurring charges look high; cancel one unused subscription to save HKD 1,499/month. - Rent is taking a large share of your budget; consider options like a roommate, renegotiating your lease, or planning for a move when feasible.
#
# ---
#
# ### Prompt
# Profile: stretched renter.
# Window: last 90 days.
# Totals: Income USD 49,119; Spend USD 52,336; Net USD -3,217.
# Top spend: Rent:32295, Shopping:6501, Groceries:2919.
# Recurring: USD 32,712 across 1 items.
# Delivery orders (approx): 3.
# Task: Provide 2-3 practical budgeting suggestions with estimated USD monthly savings.
#
# **Suggestion:**
# - Recurring charges look high; cancel one unused subscription to save USD 1,329/month. - Rent is taking a large share of your budget; consider options like a roommate, renegotiating your lease, or planning for a move when feasible.
#
# ---
#
# ### Prompt
# Profile: stretched renter.
# Window: last 180 days.
# Totals: Income HKD 62,484; Spend HKD 100,125; Net HKD -37,641.
# Top spend: Rent:45408, Shopping:16132, Utilities:9838.
# Recurring: HKD 46,908 across 2 items.
# Delivery orders (approx): 16.
# Task: Provide 2-3 practical budgeting suggestions with estimated HKD monthly savings.
#
# **Suggestion:**
# - Recurring charges look high; cancel one unused subscription to save HKD 63/month. - Rent is taking a large share of your budget; consider options like a roommate, renegotiating your lease, or planning for a move when feasible.
#
# ---
#
# ### Prompt
# Profile: comfortable renter.
# Window: last 90 days.
# Totals: Income USD 90,231; Spend USD 59,643; Net USD 30,588.
# Top spend: Rent:33081, Shopping:8953, Utilities:3977.
# Recurring: USD 33,624 across 2 items.
# Delivery orders (approx): 5.
# Task: Give 2-3 concrete budgeting tips with rough USD savings per month.
#
# **Suggestion:**
# - Recurring charges look high; cancel one unused subscription to save USD 1,527/month. - Rent is taking a large share of your budget; consider options like a roommate, renegotiating your lease, or planning for a move when feasible.
#
# ---

# %%
import shutil

# Create deployment zip
shutil.make_archive("lambda_package", "zip", "aws/package")
# Out:
# '/content/drive/MyDrive/Comp4651/Project/finadvisor-serverless/lambda_package.zip'

# %% [markdown]
# ### Deployment Steps (manual in AWS Console)
# 1. Go to AWS Lambda → Create Function.
# 2. Runtime: Python 3.10, Memory: 1024MB+, Timeout: 30s.
# 3. Upload `lambda_package.zip`.
# 4. Set handler to `lambda_handler.lambda_handler`.
# 5. Connect via API Gateway → POST `/generate`.
